# %% [markdown]
# <div align="center">
#   <img src="attachment:65fd6c9b-6e72-4805-aa6d-7a5f76323871.png" width="50%" />
# </div>
#
# | Loss Function (Mean Absolute Error) | Different Loss Function |
# | :---: | :---: |
# | ![image.png](attachment:96620484-fc4d-4012-97bb-8098f92b6945.png) | ![image.png](attachment:eb94a877-5071-41d5-b843-120bef890bda.png) |
#
# <h5 align="center">We should use Logloss Error in Logistic Regression, not the MSE</h5>

# %%
import numpy as np

y_predicted = np.array([1, 1, 0, 0, 1])
y_true = np.array([0.3, 0.7, 1, 0, 0.5])

# %%
# Manually creating Mean Absolute Error
def mae(y_true, y_predicted):
    total_error = 0
    for yt, yp in zip(y_true, y_predicted):
        total_error += abs(yt - yp)
    print("Total error:", total_error)
    
    mae = total_error / len(y_true)
    print("MAE:", mae)
    return mae

# %%
mae(y_true, y_predicted)
# Out:
# Total error: 2.5
# MAE: 0.5
# np.float64(0.5)

# %%
# Creating Mean Absolute Error using NumPy
np.mean(np.abs(y_predicted - y_true))
# Out:
# np.float64(0.5)
